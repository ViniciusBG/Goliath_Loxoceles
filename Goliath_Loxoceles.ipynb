# %% [markdown]
# # Welcome To Goliath Loxoceles

# %% [markdown]
# ### This is a web crawler to allow you to retrieve data from LastFM API and combine it with MusicBrainz infromation!

# %% [markdown]
# ![spider-312091_960_720.png](attachment:spider-312091_960_720.png)

# %% [markdown]
# ## !DON'T MODIFY THE CODE! OTHERWISE, THE SPIDER ABOVE WILL BITE YOU!
# Unless you know what you are doing :P

# %% [markdown]
# ### How to proceed:
# First of all: you won't need to write any code.
# If you have never had contact with Jupyter Notebook, don't worry, everything is very simple. Everything you need to do is to run the mandatory and optional cells.
#
# This is a cell:

# %% [markdown]
# ![Screen%20Shot%202019-11-17%20at%2012.51.40.png](attachment:Screen%20Shot%202019-11-17%20at%2012.51.40.png)

# %% [markdown]
# To run it, all you need to do is to click the cell and press **"Shift+Enter"**.
#
# After that, some cells will give you additional instructions, such as requesting your API key, the MBID code of the song you want to retrieve information, how many songs do you want to retrieve data from and so on.
#
# All you need to do is to answer these requests on the proper field and press "Enter".
# It is important to remember that not every cell will ask you something. You need to run some of them only to load the written functions.
#
# Another important issue is: if your request runs the right way, the program will show you the result right below the cell. In addition to that, there will be a CSV file in the directory of the software so you can deal with it in excel or any othe software you want.
#
# Enjoy!

# %% [markdown]
# ### Importing what we need (Don't skip!):
# Run the cell bellow to import the modules and functions you will need to do whatever you want with the app:

# %%
from Goliath_loxoceles_functions import *

# %% [markdown]
# # MusicBrainz Information

# %% [markdown]
# ### ARTIST INFORMATION

# %% [markdown]
# This function retrieves information available on MusicBrainz Database about a specific artist. To do it, you will need the MBID of the artist, wich you can find on https://musicbrainz.org.
#
# Run the following cell and follow it's instructions:

# %%
mbid = input('Please paste the IMBD of the artist you want to retrieve information:')

# %% [markdown]
# Now, run the following cell to retrieve the available information:

# %%
art_info(mbid)

# %% [markdown]
# ### TRACK INFORMATION (MUSICBRAINZ)
# This function retrieves information about a specific track on MusicBrainz Database.
# To do it, you will need the MBID of the track, wich you can find on https://musicbrainz.org.
#
# Run the following cell and follow it's instructions:

# %%
mbid_song = input('Please paste the IMBD of the track you want to retrieve information:')

# %%
track_info_MB(mbid_song)

# %% [markdown]
# ### LOW LEVEL DATA OF A SINGLE TRACK
# Retrieves information available on the AcousticBrainz platform about the low-level acoustic characteristics of a specific track.

# %% [markdown]
# ### HIGH LEVEL DATA OF A SINGLE TRACK
# Retrieves information available on the AcousticBrainz platform about the high-level acoustic characteristics of a specific track.

# %%
mbid_song2 = input('Please paste the IMBD of the track you want to retrieve information:')

# %%
single_high_level(mbid_song2)

# %% [markdown]
# # LastFM Information

# %% [markdown]
# ## API Key - !! Important !! (Don't skip!)
# Now it is time for you to generate your own API key. This is an ID for your requests at lastFM. Do not skip this step, otherwise you won't be able to grab the data you need.
# To do it, visit www.
# Run the cell below and paste the code you recieved from LastFM in order to make Goliath save your API key! Then you will not need to type/paste it again:
#
# **Run the cell below to store your API key:**

# %%
apikey = input('Please paste your API key here:')
# Out:
# Please paste your API key here:acfc63cfc5cb5aec1c1a71ce1e47ecd3

# %% [markdown]
# ### TRACK INFORMATION (LAST FM)
# Retrieves information about a specific track from LastFM database.
#
# **Run the cell below and the next to choose the artist/song you want the information:**

# %%
artist = input('Wich artist plays the song?:')
song = input('From wich song do you want retrieve information?:')

# %%
track_info_LFM(apikey, song, artist)

# %% [markdown]
# ### GEOGRAPHICAL CHART
# Retrieves information available from Last.Fm about the music preference of users in a country.
#
# **Run the cell below and the next to choose the country and the amount of data you want:**

# %%
country = input('From wich country do you want do retrieve data? - Write it in english')
limit = input("How many results per page do you want? - Write only the number(Maximum = 99)")
page = input('How many pages of results do you want?')
clean = input('Do you want us to clean the data from songs with no IMDB? (Answer: yes or no)')
clean = clean.lower()
country = country.lower()
# Out:
# From wich country do you want do retrieve data? - Write it in englishbrazil
# How many results per page do you want? - Write only the number(Maximum = 99)90
# How many pages of results do you want?4
# Do you want us to clean the data from songs with no IMDB? (Answer: yes or no)no

# %%
geo_chart(country,apikey,limit,page,clean)

# %% [markdown]
# ### GlOBAL CHART

# %%
limit = input("How many results per page do you want? - Write only the number(Maximum = 99)")
page = input('How many pages of results do you want?')
clean = input('Do you want us to clean the data from songs with no IMDB? (Answer: yes or no)')
clean = clean.lower()

# %%
global_chart(apikey,limit,page,clean)
